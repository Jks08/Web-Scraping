# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv('medifee_city_surgery_data_1.csv')
df2=pd.read_csv('medifee_city_surgery_data_2.csv')
df3=pd.read_csv('medifee_city_surgery_doctor_link_1.csv')
df4=pd.read_csv('medifee_city_surgery_doctor_link_2.csv')

# %%
df1
# Out:
#       Unnamed: 0              Surgery Name  \
# 0              0              ACL Surgery
# 1              1              ACL Surgery
# 2              2              ACL Surgery
# 3              3              ACL Surgery
# 4              4              ACL Surgery
# 5              5              ACL Surgery
# 6              6              ACL Surgery
# 7              7              ACL Surgery
# 8              8              ACL Surgery
# 9              9              ACL Surgery
# 10            10              ACL Surgery
# 11            11              ACL Surgery
# 12            12              ACL Surgery
# 13            13              ACL Surgery
# 14            14              ACL Surgery
# 15            15              ACL Surgery
# 16            16              ACL Surgery
# 17            17              ACL Surgery
# 18            18              ACL Surgery
# 19            19              ACL Surgery
# 20            20              ACL Surgery
# ...

# %%
df2
# Out:
#       Unnamed: 0          Surgery Name  \
# 0              0    Hydrocele Surgery
# 1              1    Hydrocele Surgery
# 2              2    Hydrocele Surgery
# 3              3    Hydrocele Surgery
# 4              4    Hydrocele Surgery
# 5              5    Hydrocele Surgery
# 6              6    Hydrocele Surgery
# 7              7    Hydrocele Surgery
# 8              8    Hydrocele Surgery
# 9              9    Hydrocele Surgery
# 10            10    Hydrocele Surgery
# 11            11    Hydrocele Surgery
# 12            12    Hydrocele Surgery
# 13            13    Hydrocele Surgery
# 14            14    Hydrocele Surgery
# 15            15    Hydrocele Surgery
# 16            16    Hydrocele Surgery
# 17            17    Hydrocele Surgery
# 18            18    Hydrocele Surgery
# 19            19    Hydrocele Surgery
# 20            20    Hydrocele Surgery
# 21            21    Hydrocele Surgery
# 22            22    Hydrocele Surgery
# ...

# %%
df3
# Out:
#     Unnamed: 0                           Surgery       City  \
# 0            0                      ACL Surgery   Bangalore
# 1            1                       ACL Surgery      India
# 2            2                      ACL Surgery     Chennai
# 3            3                      ACL Surgery      Mumbai
# 4            4                      ACL Surgery   New Delhi
# 5            5                      ACL Surgery        Pune
# 6            6                       ACL Surgery      India
# 7            7                      Angioplasty   Bangalore
# 8            8                      Angioplasty     Chennai
# 9            9                      Angioplasty   Hyderabad
# 10          10                      Angioplasty      Mumbai
# 11          11                      Angioplasty   New Delhi
# 12          12                      Angioplasty        Pune
# 13          13                Bariatric Surgery   Bangalore
# 14          14                Bariatric Surgery     Chennai
# ...

# %%
df4
# Out:
#     Unnamed: 0                    Surgery       City  \
# 0            0  Knee Replacement Surgery   Bangalore
# 1            1   Knee Replacement Surgery      India
# 2            2  Knee Replacement Surgery     Chennai
# 3            3  Knee Replacement Surgery   Hyderabad
# 4            4  Knee Replacement Surgery      Mumbai
# 5            5  Knee Replacement Surgery   New Delhi
# 6            6  Knee Replacement Surgery        Pune
# 7            7             Piles Surgery   Bangalore
# 8            8             Piles Surgery     Chennai
# 9            9             Piles Surgery      Mumbai
# 10          10             Piles Surgery   New Delhi
# 11          11             Piles Surgery        Pune
# 12          12             Spine Surgery   Bangalore
# 13          13             Spine Surgery     Chennai
# 14          14             Spine Surgery      Mumbai
# 15          15             Spine Surgery   New Delhi
# 16          16             Spine Surgery        Pune
#
# ...

# %%
df5=df3.append([df4])

# %%
df5
# Out:
#     Unnamed: 0                           Surgery       City  \
# 0            0                      ACL Surgery   Bangalore
# 1            1                       ACL Surgery      India
# 2            2                      ACL Surgery     Chennai
# 3            3                      ACL Surgery      Mumbai
# 4            4                      ACL Surgery   New Delhi
# 5            5                      ACL Surgery        Pune
# 6            6                       ACL Surgery      India
# 7            7                      Angioplasty   Bangalore
# 8            8                      Angioplasty     Chennai
# 9            9                      Angioplasty   Hyderabad
# 10          10                      Angioplasty      Mumbai
# 11          11                      Angioplasty   New Delhi
# 12          12                      Angioplasty        Pune
# 13          13                Bariatric Surgery   Bangalore
# 14          14                Bariatric Surgery     Chennai
# ...

# %%
df16=df5

# %%
df16.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df16
# Out:
#                              Surgery       City  \
# 0                       ACL Surgery   Bangalore
# 1                        ACL Surgery      India
# 2                       ACL Surgery     Chennai
# 3                       ACL Surgery      Mumbai
# 4                       ACL Surgery   New Delhi
# 5                       ACL Surgery        Pune
# 6                        ACL Surgery      India
# 7                       Angioplasty   Bangalore
# 8                       Angioplasty     Chennai
# 9                       Angioplasty   Hyderabad
# 10                      Angioplasty      Mumbai
# 11                      Angioplasty   New Delhi
# 12                      Angioplasty        Pune
# 13                Bariatric Surgery   Bangalore
# 14                Bariatric Surgery     Chennai
# 15                Bariatric Surgery      Mumbai
# 16                Bariatric Surgery   New Delhi
# 17                Bariatric Surgery        Pune
# ...

# %%
df16.insert(loc=0, column='S.no', value=np.arange(len(df16)))

# %%
df16.set_index("S.no",inplace=True)

# %%
df16
# Out:
#                                Surgery       City  \
# S.no
# 0                         ACL Surgery   Bangalore
# 1                          ACL Surgery      India
# 2                         ACL Surgery     Chennai
# 3                         ACL Surgery      Mumbai
# 4                         ACL Surgery   New Delhi
# 5                         ACL Surgery        Pune
# 6                          ACL Surgery      India
# 7                         Angioplasty   Bangalore
# 8                         Angioplasty     Chennai
# 9                         Angioplasty   Hyderabad
# 10                        Angioplasty      Mumbai
# 11                        Angioplasty   New Delhi
# 12                        Angioplasty        Pune
# 13                  Bariatric Surgery   Bangalore
# 14                  Bariatric Surgery     Chennai
# 15                  Bariatric Surgery      Mumbai
# 16                  Bariatric Surgery   New Delhi
# 17                  Bariatric Surgery        Pune
# ...

# %%
df16
# Out:
#                                Surgery       City  \
# S.no
# 0                         ACL Surgery   Bangalore
# 1                          ACL Surgery      India
# 2                         ACL Surgery     Chennai
# 3                         ACL Surgery      Mumbai
# 4                         ACL Surgery   New Delhi
# 5                         ACL Surgery        Pune
# 6                          ACL Surgery      India
# 7                         Angioplasty   Bangalore
# 8                         Angioplasty     Chennai
# 9                         Angioplasty   Hyderabad
# 10                        Angioplasty      Mumbai
# 11                        Angioplasty   New Delhi
# 12                        Angioplasty        Pune
# 13                  Bariatric Surgery   Bangalore
# 14                  Bariatric Surgery     Chennai
# 15                  Bariatric Surgery      Mumbai
# 16                  Bariatric Surgery   New Delhi
# 17                  Bariatric Surgery        Pune
# ...

# %%
df16.to_csv("medifee_city_surgery_doctor.csv")

# %%
df16
# Out:
#           Surgery Name                                      Hospital Name  \
# S.no
# 0         ACL Surgery                       Manipal Hospital (Whitefield)
# 1         ACL Surgery                 Aster CMI Hospital (Sahakara Nagar)
# 2         ACL Surgery                           Amrutha Orthopedic Centre
# 3         ACL Surgery                  Spine Care and Ortho Care Hospital
# 4         ACL Surgery                         Ramani Orthopaedic Hospital
# 5         ACL Surgery                     Sparsh hospital (Infantry Road)
# 6         ACL Surgery                            Sun Orthopaedic Hospital
# 7         ACL Surgery                Apollo Hospitals (Bannerghatta Road)
# 8         ACL Surgery                         Jayanagar Orthopedic Centre
# 9         ACL Surgery                                 BGS Global Hospital
# 10        ACL Surgery                                Sakra World Hospital
# 11        ACL Surgery                                Rama rau poly clinic
# ...

# %%
df16
# Out:
#                                Surgery       City  \
# S.no
# 0                         ACL Surgery   Bangalore
# 1                          ACL Surgery      India
# 2                         ACL Surgery     Chennai
# 3                         ACL Surgery      Mumbai
# 4                         ACL Surgery   New Delhi
# 5                         ACL Surgery        Pune
# 6                          ACL Surgery      India
# 7                         Angioplasty   Bangalore
# 8                         Angioplasty     Chennai
# 9                         Angioplasty   Hyderabad
# 10                        Angioplasty      Mumbai
# 11                        Angioplasty   New Delhi
# 12                        Angioplasty        Pune
# 13                  Bariatric Surgery   Bangalore
# 14                  Bariatric Surgery     Chennai
# 15                  Bariatric Surgery      Mumbai
# 16                  Bariatric Surgery   New Delhi
# 17                  Bariatric Surgery        Pune
# ...
